# %%
import numpy as np
import pandas as pd

import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GroupKFold

from scipy import stats
from sklearn import preprocessing 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.scorer import make_scorer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from statsmodels.tsa.stattools import adfuller

import statsmodels
from sklearn.compose import ColumnTransformer
import statsmodels.api as sm
from statsmodels.formula.api import ols

import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
from pandas import Timestamp

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt 
from tbats import TBATS, BATS

import xgboost as xgb
from xgboost import XGBRegressor 
from xgboost.sklearn import XGBClassifier # sklearn’s Grid Search with parallel processing
from xgboost import plot_importance
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
from catboost import CatBoostRegressor
from pmdarima.arima import auto_arima
pd.set_option('display.max_rows',None)

import itertools

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DF_File_sample.csv')
data['SKU_Customer'] = data['DemandCustomer'] + '_' + data['SKU10']
data_labels = data['SKU_Customer'] 
data.drop(['DemandCustomer', 'SKU10'], axis =1, inplace = True)

# %%
data['year_week'] = data['Year'].astype(str) + '-' + data['Week_No'].astype(str)
data['date'] = data['year_week'].apply(lambda x: datetime.datetime.strptime(x + '-4',  "%G-%V-%w"))

# %%
first_null = data.groupby('date').Sales.sum().loc[lambda x: x == 0].sort_values().index[0]
data = data[data.date < first_null]

first_26_week = pd.Series(sorted(data['date'].unique())).iloc[-26]
# first_34_week = pd.Series(sorted(data['date'].unique())).iloc[-34]

data.set_index('date', inplace = True)
data = data.iloc[np.lexsort((data.SKU_Customer.values, data.index)), [5, 7]]

# %%
train = data[data.index < first_26_week]
test = data[data.index >= first_26_week]

# %%
perc = 25
lenth = int(len(train)*(perc/100))
valid = train.tail(lenth)
Train = train.tail(-lenth)

# %% [markdown]
# ## Modeling:

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return (np.mean(np.abs(y_true - y_pred)) / np.mean(y_true)) * 100

# %%
def mape_by_month(y_true, y_pred): 
    y_true2 = pd.DataFrame(y_true.copy())
    y_true2['day'] = pd.to_datetime(y_true2.index, format='%d-%m-%Y',infer_datetime_format=True)
    y_true2['month'] = y_true2.day.dt.month
    y_true2['year'] = y_true2.day.dt.year  
    y_true2['Sales_pred'] = np.where(y_pred < 0, 0, y_pred)
    pred = y_true2.groupby(['SKU_Customer', 'year', 'month']).Sales_pred.sum().values
    true = y_true2.groupby(['SKU_Customer', 'year', 'month']).Sales.sum().values
    return mape(true, pred)

# %% [markdown]
# ### Avto_ARIMA:

# %%
SKU_Customer_list = data.SKU_Customer.unique()

# %%
period = 26
previous_df = pd.DataFrame()
forecast_dates = pd.to_datetime(test.index.unique().sort_values().values, format = '%Y-%m-%d')

for i in SKU_Customer_list:
    model = auto_arima(train[train.SKU_Customer == i].Sales, 
                         start_p = 1,
                         start_q = 1,
                         max_p = 3,
                         max_q = 3,
                         m=12,
                         start_P = 0,
                         seasonal = True,
                         d =1,
                         D = 1,
                         trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)
    
    model.fit(train[train.SKU_Customer == i].Sales)

    future_forecast, confint  = model.predict(n_periods = period, return_conf_int=True)
    last_df = pd.DataFrame({'date': forecast_dates, 
                            'SKU_Customer': i,
                            'prediction': future_forecast,
                            'conf_low': confint[ :,0],
                            'conf_upper': confint[ :,1]})
    
    previous_df = pd.concat([previous_df, last_df], ignore_index = True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3091.775, BIC=3107.877, Fit time=1.957 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3267.018, BIC=3273.458, Fit time=0.116 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3175.254, BIC=3188.135, Fit time=0.556 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3090.142, BIC=3103.024, Fit time=1.187 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3090.344, BIC=3106.446, Fit time=1.832 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3193.863, BIC=3203.524, Fit time=0.293 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=3089.725, BIC=3105.827, Fit time=3.295 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=3091.357, BIC=3110.679, Fit time=3.965 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=3151.689, BIC=3164.570, Fit time=2.322 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=3091.308, BIC=3110.630, Fit time=3.950 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=3095.065, BIC=3117.608, Fit time=5.366 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3093.308, BIC=3112.630, Fit time=5.290 seconds
# Total fit time: 30.134 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3264.655, BIC=3280.757, Fit time=1.909 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3483.015, BIC=3489.455, Fit time=0.174 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3409.682, BIC=3422.563, Fit time=0.251 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3263.891, BIC=3276.772, Fit time=1.396 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3266.514, BIC=3282.616, Fit time=1.837 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3364.289, BIC=3373.950, Fit time=0.209 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=3270.586, BIC=3286.688, Fit time=4.240 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3266.929, BIC=3286.251, Fit time=4.904 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=3363.415, BIC=3373.076, Fit time=0.358 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3264.332, BIC=3280.434, Fit time=1.770 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3262.151, BIC=3281.473, Fit time=2.135 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3289.559, BIC=3312.102, Fit time=2.389 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=3359.258, BIC=3375.360, Fit time=0.588 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=3305.159, BIC=3327.701, Fit time=4.573 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=3306.342, BIC=3332.105, Fit time=6.314 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3305.604, BIC=3328.146, Fit time=2.465 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=3270.701, BIC=3293.244, Fit time=3.132 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=3319.507, BIC=3345.270, Fit time=3.202 seconds
# Total fit time: 41.851 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2905.307, BIC=2921.409, Fit time=1.387 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3110.512, BIC=3116.952, Fit time=0.027 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3021.599, BIC=3034.480, Fit time=0.574 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2904.576, BIC=2917.457, Fit time=1.236 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2906.638, BIC=2922.739, Fit time=1.952 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=2990.683, BIC=3000.344, Fit time=0.170 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2906.576, BIC=2922.677, Fit time=15.558 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2908.166, BIC=2927.488, Fit time=5.081 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=3004.874, BIC=3014.535, Fit time=0.482 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2905.097, BIC=2921.199, Fit time=1.618 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2903.739, BIC=2923.061, Fit time=1.820 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=2905.843, BIC=2928.386, Fit time=2.697 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=2986.239, BIC=3002.341, Fit time=0.509 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=2905.739, BIC=2928.281, Fit time=4.371 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=2907.750, BIC=2933.513, Fit time=5.768 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2909.304, BIC=2931.846, Fit time=2.296 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=2905.467, BIC=2928.009, Fit time=2.867 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=2930.537, BIC=2956.300, Fit time=2.911 seconds
# Total fit time: 51.325 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2941.444, BIC=2957.546, Fit time=1.830 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3157.707, BIC=3164.148, Fit time=0.019 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3059.110, BIC=3071.991, Fit time=0.563 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=
seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3010.714, BIC=3026.815, Fit time=1.811 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3013.428, BIC=3032.750, Fit time=1.707 seconds
# Total fit time: 16.867 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2718.132, BIC=2734.234, Fit time=1.767 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=2842.004, BIC=2848.444, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=2788.918, BIC=2801.799, Fit time=0.502 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2716.201, BIC=2729.082, Fit time=1.236 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2718.197, BIC=2734.299, Fit time=1.290 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=2810.113, BIC=2819.774, Fit time=0.058 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2718.194, BIC=2734.296, Fit time=4.118 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2720.197, BIC=2739.519, Fit time=3.852 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=2755.857, BIC=2765.518, Fit time=0.540 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2718.150, BIC=2734.251, Fit time=1.577 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=2720.201, BIC=2739.523, Fit time=1.985 seconds
# Total fit time: 16.941 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2938.264, BIC=2954.366, Fit time=1.834 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3088.899, BIC=3095.340, Fit time=0.015 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=2991.940, BIC=3004.821, Fit time=0.564 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2936.545, BIC=2949.426, Fit time=1.177 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2937.013, BIC=2953.115, Fit time=1.295 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3029.152, BIC=3038.813, Fit time=0.162 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2936.099, BIC=2952.200, Fit time=4.089 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2937.910, BIC=2957.232, Fit time=4.004 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=2984.681, BIC=2997.562, Fit time=2.285 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=2937.907, BIC=2957.229, Fit time=3.481 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=2940.099, BIC=2962.642, Fit time=4.818 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2939.258, BIC=2958.580, Fit time=4.251 seconds
# Total fit time: 27.981 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3120.044, BIC=3136.146, Fit time=1.862 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3357.389, BIC=3363.829, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3231.338, BIC=3244.219, Fit time=0.597 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3125.949, BIC=3138.831, Fit time=1.625 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3124.224, BIC=3143.546, Fit time=2.090 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3225.967, BIC=3238.848, Fit time=0.254 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=3121.965, BIC=3141.287, Fit time=4.482 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3124.316, BIC=3146.859, Fit time=4.961 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3123.608, BIC=3142.930, Fit time=2.115 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=3167.978, BIC=3180.859, Fit time=0.884 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3121.415, BIC=3140.737, Fit time=1.902 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=3249.429, BIC=3259.090, Fit time=0.374 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3124.320, BIC=3146.862, Fit time=2.224 seconds
# Total fit time: 23.391 seconds

# %%
pred_ARIMA = pd.merge(test.reset_index(), previous_df, on = ['date', 'SKU_Customer']).set_index('date')
mape_by_month(pred_ARIMA, pred_ARIMA['prediction'])
# Out:
# 45.67192254187942

# %% [markdown]
# ## Holt Winters:

# %%
period = 26
previous_df_HW = pd.DataFrame()
forecast_dates = pd.to_datetime(test.index.unique().sort_values().values, format = '%Y-%m-%d')

for i in SKU_Customer_list:
    model_HW = ExponentialSmoothing(np.asarray(train[train.SKU_Customer == i].Sales),seasonal_periods=52, trend='add', seasonal='add')
    model_HW = model_HW.fit(smoothing_level=0.1, smoothing_slope=0.001, smoothing_seasonal=0.05)
    pred_HW = model_HW.forecast(period) 

    last_df_HW = pd.DataFrame({'date': forecast_dates, 
                            'SKU_Customer': i,
                            'prediction': pred_HW})
    
    previous_df_HW = pd.concat([previous_df_HW, last_df_HW], ignore_index = True)

# %%
pred_HW = pd.merge(test.reset_index(), previous_df_HW, on = ['date', 'SKU_Customer']).set_index('date')
mape_by_month(pred_HW, pred_HW['prediction'])

# %%
# testing

period = 26
previous_df_HW = pd.DataFrame()
forecast_dates = pd.to_datetime(test.index.unique().sort_values().values, format = '%Y-%m-%d')

mape_pred = 150
for alpha in np.arange(0, 1, .1):
    for beta in np.arange(0, 1, .1):
        for gamma in np.arange(0, 1, .1):           
            for i in SKU_Customer_list:
                model_HW = ExponentialSmoothing(np.asarray(train[train.SKU_Customer == i].Sales),seasonal_periods=52, trend='add', seasonal='add')
                model_HW = model_HW.fit(smoothing_level=alpha, smoothing_slope=beta, smoothing_seasonal=gamma)
                pred_HW = model_HW.forecast(period) 

                last_df_HW = pd.DataFrame({'date': forecast_dates, 
                                        'SKU_Customer': i,
                                        'prediction': pred_HW})
    
                previous_df_HW = pd.concat([previous_df_HW, last_df_HW], ignore_index = True)  
                pred_HW = pd.merge(test.reset_index(), previous_df_HW, on = ['date', 'SKU_Customer']).set_index('date')
                mape_potential_pred = mape_by_month(pred_HW, pred_HW['prediction'])
                if mape_potential_pred < mape_pred:
                    mape_pred = mape_potential_pred
                    param = [alpha, beta, gamma]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-ca404cb0aa0f> in <module>
#      19
#      20                 previous_df_HW = pd.concat([previous_df_HW, last_df_HW], ignore_index = True)
# ---> 21                 pred_HW = pd.merge(test.reset_index(), previous_df_HW, on = ['date', 'SKU_Customer']).set_index('date')
#      22                 mape_potential_pred = mape_by_month(pred_HW, pred_HW['prediction'])
#      23                 if mape_potential_pred < mape_pred:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
#     644         ldata, rdata = self.left._data, self.right._data
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     857             )
#     858         else:
# --> 859             (left_indexer, right_indexer) = self._get_join_indexers()
#     860
#     861             if self.right_index:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     836         """ return the join indexers """
#     837         return _get_join_indexers(
# --> 838             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     839         )
#     840
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1302
#    1303     # get left & right join labels and num. of levels at each location
# -> 1304     llab, rlab, shape = map(list, zip(*map(fkeys, left_keys, right_keys)))
#    1305
#    1306     # get flat i8 keys from label lists
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1901
#    1902     llab = rizer.factorize(lk)
# -> 1903     rlab = rizer.factorize(rk)
#    1904
#    1905     count = rizer.get_count()
#
# pandas\_libs\hashtable.pyx in pandas._libs.hashtable.Factorizer.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:

# %%
param
# Out:
# [0.0, 0.0, 0.0]

# %%
for i in SKU_Customer_list:
    model_HW = ExponentialSmoothing(np.asarray(train[train.SKU_Customer == i].Sales),seasonal_periods=52, trend='add', seasonal='add')
    model_HW = model_HW.fit(smoothing_level=param[0], smoothing_slope=param[1], smoothing_seasonal=param[2])
    pred_HW = model_HW.forecast(period) 

    last_df_HW = pd.DataFrame({'date': forecast_dates, 
                            'SKU_Customer': i,
                            'prediction': pred_HW})
    
    previous_df_HW = pd.concat([previous_df_HW, last_df_HW], ignore_index = True)

# %%
pred_HW = pd.merge(test.reset_index(), previous_df_HW, on = ['date', 'SKU_Customer']).set_index('date')
mape_by_month(pred_HW, pred_HW['prediction'])
# Out:
# 29.030974020832474

# %% [markdown]
# ## TBATS:

# %%
period = 26
previous_df_TBATS = pd.DataFrame()
forecast_dates = pd.to_datetime(test.index.unique().sort_values().values, format = '%Y-%m-%d')
estimator = TBATS(seasonal_periods = [52.18])

for i in SKU_Customer_list:
    model_TBATS = estimator.fit(train[train.SKU_Customer == i].Sales)
    pred_TBATS = model_TBATS.forecast(steps = period)

    last_df = pd.DataFrame({'date': forecast_dates, 
                            'SKU_Customer': i,
                            'prediction': pred_TBATS})
    
    previous_df_TBATS = pd.concat([previous_df_TBATS, last_df], ignore_index = True)

# %%
pred_TBATS = pd.merge(test.reset_index(), previous_df_TBATS, on = ['date', 'SKU_Customer']).set_index('date')
mape_by_month(pred_TBATS, pred_TBATS['prediction'])
# Out:
# 39.42492818923642

# %% [markdown]
# ## Prophet:

# %%
from fbprophet import Prophet
import logging

logging.getLogger().setLevel(logging.ERROR)

# %%
period = 26

train_Prophet = train[['SKU_Customer', 'Sales']].reset_index()
test_Prophet = test[['SKU_Customer', 'Sales']].reset_index()
train_Prophet.columns = ['ds', 'SKU_Customer', 'y']
test_Prophet.columns = ['ds', 'SKU_Customer', 'y']

# %%
period = 26
previous_df_Prophet = pd.DataFrame()
forecast_dates = pd.to_datetime(test.index.unique().sort_values().values, format = '%Y-%m-%d')

for i in SKU_Customer_list:
    model_Prophet = Prophet()
    model_Prophet.fit(train_Prophet[train_Prophet.SKU_Customer == i].loc[:, ['ds', 'y']])
    future_Prophet = model_Prophet.make_future_dataframe(periods=period, freq = 'W-THU')
    pred_Prophet = model_Prophet.predict(future_Prophet)
    pred_Prophet = pred_Prophet.loc[-period:, 'yhat']
    
    last_df_Prophet = pd.DataFrame({'date': forecast_dates, 
                            'SKU_Customer': i,
                            'prediction': pred_Prophet})
    
    previous_df_Prophet = pd.concat([previous_df_Prophet, last_df_Prophet], ignore_index = True)

# %%
pred_Prophet = pd.merge(test.reset_index(), previous_df_Prophet, on = ['date', 'SKU_Customer']).set_index('date')
mape_by_month(pred_TBATS, pred_Prophet['prediction'])
# Out:
# 47.97456532684557
