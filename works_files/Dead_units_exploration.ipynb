# %%
import gc
import re
import math
import json
import os
import numpy as np
import pandas as pd
from scipy import stats

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
from mlxtend.regressor import StackingRegressor

# %%
import datetime
from datetime import date
from datetime import timedelta
from datetime import datetime
from dateutil.relativedelta import relativedelta
import calendar

# %%
# pip install isoweek
# pip install tsfresh

# %%
from isoweek import Week

# %%
import pickle

# %%
from time import time

# %%
from sklearn.externals import joblib

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# # Preparations:

# %%
df = pd.read_csv('CPN_Fractal_fct_468053.txt', sep='|')
df['date'] = df['Period Description Short'].apply(lambda x: pd.to_datetime(x[6:14]) - timedelta(days=2))

df = df[df['Market Display Name'].apply(lambda x: 'CVS' not in x)]
df = df[['Market Display Name', 'date','UPC', 'Units']]
df['Market_UPC'] = df['Market Display Name'] + df['UPC'].astype(str)
df.sort_values(by = ['Market_UPC', 'date'], inplace = True)

# %% [markdown]
# ### add all rows with dates(if date doesn`t exist, add date with zero 'Unit')

# %%
max_date = df['date'].max()

def reindex_from_min_day(df):
    dates = pd.date_range(df.index.min(), max_date, freq='W-THU')
    idx = pd.Index(dates, name='date')
    return df.reindex(idx,fill_value=0)

df_new = df
df_new.set_index('date', inplace = True)
df_new = df_new.groupby('Market_UPC').apply(reindex_from_min_day)
df_new.shape
# Out:
# (36850, 4)

# %% [markdown]
# ### delete all zero 'Unit' and save only the last one zero row:

# %%
df_new.drop('Market_UPC', axis = 1, inplace = True)
df_new.reset_index(inplace = True)

# %%
df_new = df_new[(df_new.Units != 0) | (df_new.date == '2018-12-27')]

# %%
df_new.head(2)
# Out:
#                    Market_UPC       date Market Display Name           UPC  \
# 0  Target City TA201219708420 2018-06-07      Target City TA  201219708420
# 2  Target City TA201219708420 2018-06-21      Target City TA  201219708420
#
#    Units
# 0    1.0
# 2    1.0

# %%
df_market_upc = df_new[['Market Display Name', 'UPC']]

# %% [markdown]
# ### add Market_UPC

# %%
df_market_upc['Market_UPC'] = df_market_upc['Market Display Name'] + df_market_upc['UPC'].astype(str)

# %% [markdown]
# ### add max date

# %%
max_dates = pd.DataFrame(df[df.Units >0] \
                         .reset_index() \
                         .groupby('Market_UPC').max()['date']) \
                         .reset_index() \
                         .rename(columns = {'date': 'max_date'})
# max_dates_cnt = max_dates.groupby(['date']).count()

# %%
df_market_upc = df_market_upc.merge(max_dates, how = 'left', on = 'Market_UPC')

# %% [markdown]
# ### dead_flag (season_type - no data after 2018)

# %%
df_market_upc['dead_reason'] = np.where(df_market_upc.max_date < '2018-01-01', 'season', 'alive')
df_market_upc['dead_season'] = np.where(df_market_upc.max_date < '2018-01-01', 1, 0)

# %% [markdown]
# ## Add another features:

# %%
df_market_upc_pre = df_new[['Market_UPC', 'date']] \
                      .groupby(['Market_UPC'])['date'].apply(list) \
                      .apply(np.diff)

# %% [markdown]
# ### dead_flag few observations (date less than 4 )

# %%
diff_date_len = df_market_upc_pre.apply(lambda x: len(x))

# %%
diff_date_len = pd.DataFrame(diff_date_len).reset_index().rename(columns = {'date': 'date_qty'})

# %%
df_market_upc = df_market_upc.merge(diff_date_len, how='left', on = 'Market_UPC')

# %% [markdown]
# ### dead_flag (data is empty more than 1 season period)

# %%
df_market_upc
# Out:
#                  Market Display Name           UPC  \
# 0                     Target City TA    3500046280
# 1                     Target City TA  201219708420
# 2                  Target Express TA  201219708420
# 3                  Target GM Only TA    3500046280
# 4                  Target GM Only TA  201219708420
# 5                       Target GM TA    3500046280
# 6                       Target GM TA  201219708420
# 7                   Target Pfresh TA    2848433070
# 8                   Target Pfresh TA    2848433540
# 9                   Target Pfresh TA    3500046280
# 10                  Target Pfresh TA    3700000667
# 11                  Target Pfresh TA  201219708420
# 12                  Target Pfresh TA  201274048514
# 13             Target Supercenter TA    2848433070
# 14             Target Supercenter TA    3500046280
# 15             Target Supercenter TA  201219708420
# 16           Target Total Atlanta TA    3500046280
# 17           Target Total Atlanta TA  201219708420
# 18     Target Total Atlanta xAOC Rem    2413116200
# 19     Target Total Atlanta xAOC Rem    3700098124
# 20     Target Total Atlanta xAOC Rem    4288742446
# 21     Target Total Atlanta xAOC Rem   70307407023
# 22     Target Total Atlanta xAOC Rem  201541163524
# 23     Target Total Atlanta xAOC Rem  201656172544
# 24         Target Total Baltimore TA    3500046280
# 25         Target Total Baltimore TA  201219708420
# 26   Target Total Baltimore xAOC Rem    1117112649
# 27   Target Total Baltimore xAOC Rem    3700098124
# 28   Target Total Baltimore xAOC Rem    7289413864
# 29   Target Total Baltimore xAOC Rem  201541163524
# ..                               ...           ...
# 397            Target Total xAOC Rem    1117112649
# 398            Target Total xAOC Rem    2413116200
# 399            Target Total xAOC Rem    2413132927
# 400            Target Total xAOC Rem    2829524424
# 401            Target Total xAOC Rem    3500000969
# 402            Target Total xAOC Rem    3500000973
# 403            Target Total xAOC Rem    3500046280
# 404            Target Total xAOC Rem    3700023176
# 405            Target Total xAOC Rem    3700035674
# 406            Target Total xAOC Rem    3700098124
# 407            Target Total xAOC Rem    4288742446
# 408            Target Total xAOC Rem    5170077412
# 409            Target Total xAOC Rem    7155540125
# 410            Target Total xAOC Rem    7289413864
# 411            Target Total xAOC Rem    7518204943
# 412            Target Total xAOC Rem   70307407023
# 413            Target Total xAOC Rem   72242950018
# 414            Target Total xAOC Rem   73291322864
# 415            Target Total xAOC Rem   74917409729
# 416            Target Total xAOC Rem   81181702035
# 417            Target Total xAOC Rem   83881000971
# 418            Target Total xAOC Rem   87067800485
# 419            Target Total xAOC Rem  200739851777
# 420            Target Total xAOC Rem  200744528896
# 421            Target Total xAOC Rem  200836155392
# 422            Target Total xAOC Rem  201369447426
# 423            Target Total xAOC Rem  201541163524
# 424            Target Total xAOC Rem  201656172544
# 425            Target Total xAOC Rem  202003322369
# 426            Target Total xAOC Rem  202015066624
#
#                                              date_diff  \
# 0            0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 1             0
# 0  14 days
# 1   7 days
# 2   7 days
# 3 ...
# 2            0
# 0 14 days
# 1 28 days
# 2 14 days
# 3  7 d...
# 3            0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 4            0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 5            0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 6            0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 7                                         0
# 0 126 days
# 8                              0
# 0 252 days
# 1 217 days
# 9              0
# 0    7 days
# 1    7 days
# 2    7 day...
# 10              Empty DataFrame
# Columns: [0]
# Index: []
# 11           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 12                             0
# 0 196 days
# 1  91 days
# 13                             0
# 0 329 days
# 1  42 days
# 14            0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 15           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 16          0
# 0 7 days
# 1 7 days
# 2 7 days
# 3 7 days
# 4...
# 17           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 18            0
# 0  14 days
# 1  21 days
# 2  28 days
# 3 ...
# 19           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 20            0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 21           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 22           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 23            0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 24            0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 25           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 26            0
# 0  21 days
# 1   7 days
# 2   7 days
# 3 ...
# 27           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 28              Empty DataFrame
# Columns: [0]
# Index: []
# 29           0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# ..                                                 ...
# 397           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 398           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 399                    0
# 0  7 days
# 1 14 days
# 2 49 days
# 400             Empty DataFrame
# Columns: [0]
# Index: []
# 401                                       0
# 0 119 days
# 402           0
# 0   7 days
# 1  21 days
# 2  91 days
# 3 ...
# 403           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 404            0
# 0    7 days
# 1   28 days
# 2   49 day...
# 405             Empty DataFrame
# Columns: [0]
# Index: []
# 406           0
# 0  14 days
# 1   7 days
# 2   7 days
# 3 ...
# 407          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 408                                0
# 0 7 days
# 1 7 days
# 409                            0
# 0 147 days
# 1  49 days
# 410                    0
# 0 28 days
# 1 35 days
# 2 77 days
# 411            0
# 0    7 days
# 1    7 days
# 2    7 day...
# 412            0
# 0    7 days
# 1    7 days
# 2    7 day...
# 413           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 414           0
# 0  14 days
# 1 105 days
# 2 245 days
# 3 ...
# 415           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 416           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 417             Empty DataFrame
# Columns: [0]
# Index: []
# 418             Empty DataFrame
# Columns: [0]
# Index: []
# 419                                         0
# 0 7 days
# 420             Empty DataFrame
# Columns: [0]
# Index: []
# 421          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 422                                         0
# 0 7 days
# 423          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 424           0
# 0   7 days
# 1   7 days
# 2   7 days
# 3 ...
# 425          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 426                                       0
# 0 266 days
#
#                                       Market_UPC   max_date dead_reason  \
# 0                       Target City TA3500046280 2017-03-23      season
# 1                     Target City TA201219708420 2018-12-27       alive
# 2                  Target Express TA201219708420 2018-12-20       alive
# 3                    Target GM Only TA3500046280 2017-04-06      season
# 4                  Target GM Only TA201219708420 2018-12-27       alive
# 5                         Target GM TA3500046280 2017-04-06      season
# 6                       Target GM TA201219708420 2018-12-27       alive
# 7                     Target Pfresh TA2848433070 2018-09-13       alive
# 8                     Target Pfresh TA2848433540 2018-07-26       alive
# 9                     Target Pfresh TA3500046280 2018-12-06       alive
# 10                    Target Pfresh TA3700000667 2018-09-27       alive
# 11                  Target Pfresh TA201219708420 2018-12-27       alive
# 12                  Target Pfresh TA201274048514 2018-03-29       alive
# 13               Target Supercenter TA2848433070 2018-07-12       alive
# 14               Target Supercenter TA3500046280 2017-04-20      season
# 15             Target Supercenter TA201219708420 2018-12-27       alive
# 16             Target Total Atlanta TA3500046280 2017-03-09      season
# 17           Target Total Atlanta TA201219708420 2018-12-27       alive
# 18       Target Total Atlanta xAOC Rem2413116200 2018-10-11       alive
# 19       Target Total Atlanta xAOC Rem3700098124 2018-12-27       alive
# 20       Target Total Atlanta xAOC Rem4288742446 2018-12-27       alive
# 21      Target Total Atlanta xAOC Rem70307407023 2017-03-30      season
# 22     Target Total Atlanta xAOC Rem201541163524 2018-12-27       alive
# 23     Target Total Atlanta xAOC Rem201656172544 2018-07-19       alive
# 24           Target Total Baltimore TA3500046280 2017-03-30      season
# 25         Target Total Baltimore TA201219708420 2018-12-27       alive
# 26     Target Total Baltimore xAOC Rem1117112649 2018-12-06       alive
# 27     Target Total Baltimore xAOC Rem3700098124 2018-12-27       alive
# 28     Target Total Baltimore xAOC Rem7289413864 2017-03-09      season
# 29   Target Total Baltimore xAOC Rem201541163524 2018-12-27       alive
# ..                                           ...        ...         ...
# 397              Target Total xAOC Rem1117112649 2018-12-27       alive
# 398              Target Total xAOC Rem2413116200 2018-12-27       alive
# 399              Target Total xAOC Rem2413132927 2017-03-23      season
# 400              Target Total xAOC Rem2829524424 2018-01-11       alive
# 401              Target Total xAOC Rem3500000969 2017-07-13      season
# 402              Target Total xAOC Rem3500000973 2018-08-16       alive
# 403              Target Total xAOC Rem3500046280 2018-12-13       alive
# 404              Target Total xAOC Rem3700023176 2018-05-17       alive
# 405              Target Total xAOC Rem3700035674 2017-06-08      season
# 406              Target Total xAOC Rem3700098124 2018-12-27       alive
# 407              Target Total xAOC Rem4288742446 2018-12-27       alive
# 408              Target Total xAOC Rem5170077412 2018-12-27       alive
# 409              Target Total xAOC Rem7155540125 2017-07-27      season
# 410              Target Total xAOC Rem7289413864 2017-05-25      season
# 411              Target Total xAOC Rem7518204943 2018-08-23       alive
# 412             Target Total xAOC Rem70307407023 2018-08-02       alive
# 413             Target Total xAOC Rem72242950018 2018-12-27       alive
# 414             Target Total xAOC Rem73291322864 2018-07-19       alive
# 415             Target Total xAOC Rem74917409729 2018-12-27       alive
# 416             Target Total xAOC Rem81181702035 2018-12-27       alive
# 417             Target Total xAOC Rem83881000971 2018-03-08       alive
# 418             Target Total xAOC Rem87067800485 2017-09-14      season
# 419            Target Total xAOC Rem200739851777 2017-02-23      season
# 420            Target Total xAOC Rem200744528896 2018-10-11       alive
# 421            Target Total xAOC Rem200836155392 2017-06-22      season
# 422            Target Total xAOC Rem201369447426 2018-06-21       alive
# 423            Target Total xAOC Rem201541163524 2018-12-27       alive
# 424            Target Total xAOC Rem201656172544 2018-12-27       alive
# 425            Target Total xAOC Rem202003322369 2018-12-27       alive
# 426            Target Total xAOC Rem202015066624 2018-03-15       alive
#
#      dead_season  date_qty
# 0              0        10
# 1              0        28
# 2              0         9
# 3              0        14
# 4              0        29
# 5              0        14
# 6              0        29
# 7              1         2
# 8              1         3
# 9              0        20
# 10             1         1
# 11             0        29
# 12             1         3
# 13             1         3
# 14             0        14
# 15             0        29
# 16             0        10
# 17             0        28
# 18             0        27
# 19             0        85
# 20             0        84
# 21             0         6
# 22             0        99
# 23             0        62
# 24             0        12
# 25             0        27
# 26             0        25
# 27             0        83
# 28             1         1
# 29             0        99
# ..           ...       ...
# 397            0        97
# 398            0       103
# 399            1         4
# 400            1         1
# 401            1         2
# 402            0        10
# 403            0        68
# 404            0        12
# 405            1         1
# 406            0        92
# 407            0        95
# 408            1         2
# 409            1         3
# 410            1         4
# 411            0        32
# 412            0        21
# 413            0        52
# 414            0         5
# 415            0       103
# 416            0       103
# 417            1         1
# 418            1         1
# 419            1         2
# 420            1         1
# 421            0        25
# 422            1         2
# 423            0        99
# 424            0        99
# 425            0        67
# 426            1         2
#
# [427 rows x 8 columns]

# %%
df_market_upc_pre2['days'] = df_market_upc_pre2['days'].apply(lambda x: [0] if len(x)==0 else x)

# %%
df_market_upc_pre2['max_gap'] =  df_market_upc_pre2['days'].apply(lambda x: max(x))

# %%
df_market_upc_pre2['max_gap_flag'] =  df_market_upc_pre2['days'].apply(lambda x: 1 if (max(x) - x[-1])==0 else 0)

# %%
df_market_upc = df_market_upc.merge(df_market_upc_pre2, how='left', on = 'Market_UPC')

# %%
df_market_upc.drop(['date', 'days', 'big_gap_dead'], axis = 1, inplace = True)

# %%
df_market_upc.columns
# Out:
# Index(['Market Display Name', 'UPC', 'date_diff', 'Market_UPC', 'max_date',
#        'dead_reason', 'dead_season', 'date_qty', 'max_gap', 'max_gap_flag'],
#       dtype='object')

# %%
df_market_upc.drop(['dead_reason', 'dead_season'], inplace = True, axis = 1)

# %%
df_market_upc.columns
# Out:
# Index(['Market Display Name', 'UPC', 'date_diff', 'Market_UPC', 'max_date',
#        'date_qty', 'max_gap', 'max_gap_flag'],
#       dtype='object')

# %%
df_market_upc['date_qty_flag'] = np.where(df_market_upc['date_qty']<4,1,0)

# %%
df_market_upc.columns
# Out:
# Index(['Market Display Name', 'UPC', 'date_diff', 'Market_UPC', 'max_date',
#        'date_qty', 'max_gap', 'max_gap_flag', 'date_qty_flag'],
#       dtype='object')

# %%
df_market_upc.head()
# Out:
#   Market Display Name           UPC  \
# 0      Target City TA    3500046280
# 1      Target City TA  201219708420
# 2   Target Express TA  201219708420
# 3   Target GM Only TA    3500046280
# 4   Target GM Only TA  201219708420
#
#                                            date_diff  \
# 0          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 1           0
# 0  14 days
# 1   7 days
# 2   7 days
# 3 ...
# 2          0
# 0 14 days
# 1 28 days
# 2 14 days
# 3  7 d...
# 3          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
# 4          0
# 0  7 days
# 1  7 days
# 2  7 days
# 3  7 d...
#
#                       Market_UPC   max_date  date_qty  max_gap  max_gap_flag  \
# 0       Target City TA3500046280 2017-03-23        10      644             1
# 1     Target City TA201219708420 2018-12-27        28       14             0
# 2  Target Express TA201219708420 2018-12-20         9       35             0
# 3    Target GM Only TA3500046280 2017-04-06        14      630             1
# 4  Target GM Only TA201219708420 2018-12-27        29        7             1
#
#    date_qty_flag
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df_market_upc.to_csv('add_features.csv')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\19_10_21_Nielsen'
